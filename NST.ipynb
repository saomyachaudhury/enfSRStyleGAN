# %% [markdown]
# # **`1.`** Imports and Dependencies

# %%
# Import custom utility functions: for image processing, Gram matrix, etc.
import utils.image_utils as utils

# Import function to create a video from saved image frames (optional)
from utils.video_utils import create_video_from_intermediate_results

# PyTorch imports for building and training the neural network
import torch
from torch.optim import Adam, LBFGS         # Optimizers: Adam (gradient-based), LBFGS (quasi-Newton)
from torch.autograd import Variable         # Allows tracking gradients on tensors
import numpy as np                          # For numerical operations and random noise initialization
import os                                   # For filesystem operations like paths and directories

# %% [markdown]
# # **`2.`** Loss Function Builder

# %%
def build_loss(neural_net, optimizing_img, target_representations, content_feature_maps_index, style_feature_maps_indices, config):
    """
    Calculates the total loss from content, style, and total variation losses.

    Parameters:
    - neural_net: The pretrained CNN (e.g., VGG19) used to extract features.
    - optimizing_img: The image we are optimizing to blend content + style.
    - target_representations: A tuple/list of precomputed feature maps:
        [target_content, target_style]
    - content_feature_maps_index: Index of layer to compute content loss from.
    - style_feature_maps_indices: List of indices for style layers.
    - config: Configuration dict holding the loss weights.
    """

    # Get target content and style features from earlier layers of the model
    target_content_representation = target_representations[0]
    target_style_representation = target_representations[1]

    # Pass the current image through the network to get its feature maps
    current_set_of_feature_maps = neural_net(optimizing_img)

    # Extract the content representation from the designated content layer
    current_content_representation = current_set_of_feature_maps[content_feature_maps_index].squeeze(axis=0)

    # Calculate content loss using Mean Squared Error (MSE)
    content_loss = torch.nn.MSELoss(reduction='mean')(target_content_representation, current_content_representation)

    # Initialize style loss
    style_loss = 0.0

    # Compute Gram matrices for current image's style layers
    current_style_representation = [
        utils.gram_matrix(x) for cnt, x in enumerate(current_set_of_feature_maps) if cnt in style_feature_maps_indices
    ]

    # Calculate style loss across all selected layers (sum of MSE between Gram matrices)
    for gram_gt, gram_hat in zip(target_style_representation, current_style_representation):
        style_loss += torch.nn.MSELoss(reduction='sum')(gram_gt[0], gram_hat[0])

    # Normalize style loss by the number of style layers
    style_loss /= len(target_style_representation)

    # Total variation loss: regularization to promote image smoothness
    tv_loss = utils.total_variation(optimizing_img)

    # Total loss is a weighted combination of the three loss types
    total_loss = (
        config['content_weight'] * content_loss +
        config['style_weight'] * style_loss +
        config['tv_weight'] * tv_loss
    )

    return total_loss, content_loss, style_loss, tv_loss

# %% [markdown]
# # **`3.`** Optimization Step Builder

# %%
def make_tuning_step(neural_net, optimizer, target_representations, content_feature_maps_index, style_feature_maps_indices, config):
    """
    Creates and returns a function that performs one step of optimization.

    Parameters:
    - neural_net: The CNN model used for feature extraction.
    - optimizer: The optimizer (Adam or LBFGS) used to update image pixels.
    - target_representations: Target feature maps for content and style.
    - content_feature_maps_index: Index of CNN layer used for content loss.
    - style_feature_maps_indices: List of layers used for style loss.
    - config: Holds the weights for each loss term.
    """

    def tuning_step(optimizing_img):
        # Compute total loss and individual loss components
        total_loss, content_loss, style_loss, tv_loss = build_loss(
            neural_net, optimizing_img, target_representations,
            content_feature_maps_index, style_feature_maps_indices, config
        )

        # Backpropagate to compute gradients
        total_loss.backward()

        # Perform optimization step to update image
        optimizer.step()

        # Clear gradients for next iteration
        optimizer.zero_grad()

        return total_loss, content_loss, style_loss, tv_loss

    return tuning_step

# %% [markdown]
# ---

# %% [markdown]
# # **`4.`** Main Neural Style Transfer Function

# %% [markdown]
# ---

# %%
def neural_style_transfer(config):
    """
    Main function to perform neural style transfer. For convenience of the user the
    FUNCTION is further divided into BLOCKS for easier understanding.

    Parameters:
    - config: Dictionary containing all hyperparameters and paths.
    """
    
    # ------------------------ 📥 Block 1: Input Setup ------------------------ #
   
    # Construct full paths to the content and style images
    content_img_path = os.path.join(config['content_images_dir'], config['content_img_name'])
    style_img_path = os.path.join(config['style_images_dir'], config['style_img_name'])

    # Create a unique output folder name
    out_dir_name = 'combined_' + os.path.splitext(os.path.basename(content_img_path))[0] + '_' + os.path.splitext(os.path.basename(style_img_path))[0]

    # Define where to save the output images
    dump_path = os.path.join(config['output_img_dir'], out_dir_name)
    os.makedirs(dump_path, exist_ok=True)  # Create the directory if it doesn't exist


    # ---------------- 📡 Block 2: Load and Preprocess Images ---------------- #

    # Choose the device: GPU if available, else CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Load and preprocess the content image to target height
    content_img = utils.prepare_img(content_img_path, config['height'], device)

    # Load and preprocess the style image to same height
    style_img = utils.prepare_img(style_img_path, config['height'], device)


    # ---------------- 🖼️ Block 3: Initialize Optimization Image ---------------- #

    # Choose how to initialize the image being optimized
    if config['init_method'] == 'random':
        # Initialize with Gaussian noise (mean=0, std=90), same shape as content image
        gaussian_noise_img = np.random.normal(loc=0, scale=90., size=content_img.shape).astype(np.float32)
        init_img = torch.from_numpy(gaussian_noise_img).float().to(device)
    elif config['init_method'] == 'content':
        init_img = content_img  # Start with the content image
    else:  # 'style'
        # Resize style image to match content image's shape
        style_img_resized = utils.prepare_img(style_img_path, np.asarray(content_img.shape[2:]), device)
        init_img = style_img_resized

    # Mark image as a trainable variable (requires gradients)
    optimizing_img = Variable(init_img, requires_grad=True)


    # ---------------- 🔧 Block 4: Model and Feature Extraction ---------------- #

    # Load the model and indices for layers used in content/style loss
    neural_net, content_feature_maps_index_name, style_feature_maps_indices_names = utils.prepare_model(config['model'], device)
    print(f'Using {config["model"]} in the optimization procedure.')

    # Extract feature maps from content and style images
    content_img_set_of_feature_maps = neural_net(content_img)
    style_img_set_of_feature_maps = neural_net(style_img)

    # Select content feature from specified layer
    target_content_representation = content_img_set_of_feature_maps[content_feature_maps_index_name[0]].squeeze(0)

    # Compute style features (Gram matrices) from specified layers
    target_style_representation = [
        utils.gram_matrix(x) for cnt, x in enumerate(style_img_set_of_feature_maps)
        if cnt in style_feature_maps_indices_names[0]
    ]

    target_representations = [target_content_representation, target_style_representation]


    # ---------------- 🔁 Block 5: Optimization Loop ---------------- #

    # Set iteration counts based on optimizer
    num_of_iterations = {
        "lbfgs": 1000,
        "adam": 1000
    }

        ### ---------- 🔁 Block 5(a): Using Adam Optimizer ------- ###

    # If using Adam optimizer
    if config['optimizer'] == 'adam':
        optimizer = Adam((optimizing_img,), lr=1e1)  # High LR for faster updates
        tuning_step = make_tuning_step(
            neural_net, optimizer, target_representations,
            content_feature_maps_index_name[0], style_feature_maps_indices_names[0], config
        )
        for cnt in range(num_of_iterations[config['optimizer']]):
            total_loss, content_loss, style_loss, tv_loss = tuning_step(optimizing_img)
            with torch.no_grad():
                print(f'Adam | iteration: {cnt:03}, total loss={total_loss.item():12.4f}, content_loss={config["content_weight"] * content_loss.item():12.4f}, style loss={config["style_weight"] * style_loss.item():12.4f}, tv loss={config["tv_weight"] * tv_loss.item():12.4f}')
                utils.save_and_maybe_display(optimizing_img, dump_path, config, cnt, num_of_iterations[config['optimizer']], should_display=False)

        ### ------ 🔁 Block 5(b): Optimization using LBFGS ------- ###

    elif config['optimizer'] == 'lbfgs':
        optimizer = LBFGS((optimizing_img,), max_iter=num_of_iterations['lbfgs'], line_search_fn='strong_wolfe')
        cnt = 0

        def closure():
            nonlocal cnt
            if torch.is_grad_enabled():
                optimizer.zero_grad()
            total_loss, content_loss, style_loss, tv_loss = build_loss(
                neural_net, optimizing_img, target_representations,
                content_feature_maps_index_name[0], style_feature_maps_indices_names[0], config
            )
            if total_loss.requires_grad:
                total_loss.backward()
            with torch.no_grad():
                print(f'L-BFGS | iteration: {cnt:03}, total loss={total_loss.item():12.4f}, content_loss={config["content_weight"] * content_loss.item():12.4f}, style loss={config["style_weight"] * style_loss.item():12.4f}, tv loss={config["tv_weight"] * tv_loss.item():12.4f}')
                utils.save_and_maybe_display(optimizing_img, dump_path, config, cnt, num_of_iterations[config['optimizer']], should_display=False)
            cnt += 1
            return total_loss

        optimizer.step(closure)

    return dump_path  # Path where output images are saved

# %% [markdown]
# # **`5.`** Configuration Setup and Execution

# %%
# Get the current working directory — used as the base path for other folders.
notebook_dir = os.getcwd()

# Create a default folder to store all related data: images, outputs, etc.
default_resource_dir = os.path.join(notebook_dir, 'data')

# Define the folder path where content images are located
content_images_dir = os.path.join(default_resource_dir, 'content-images')

# Define the folder path where style images are located
style_images_dir = os.path.join(default_resource_dir, 'style-images')

# Define the folder path where output (stylized) images will be saved
output_img_dir = os.path.join(default_resource_dir, 'output-images')

# Image naming format: (padding, extension) — e.g., %04d.jpg → 0001.jpg
img_format = (4, '.jpg')  # Ensures consistent sorting and easy video creation

# %% [markdown]
# # **`6.`** Configuration Dictionary (Hyperparameters)

# %%
optimization_config = {
    # Filename of the content image to be used (must exist in content_images_dir)
    "content_img_name": "birds.jpg",

    # Filename of the style image to transfer artistic style from
    "style_img_name": "Mona_Lisa.jpg",

    # Height to resize both images to — helps standardize dimensions
    "height": 500,  # Reasonable size for quality + efficiency trade-off

    # Loss weights — how much importance to assign to each type of loss:
    "content_weight": 1e5,  # High weight: preserves structure of the original image
    "style_weight": 1e-1,    # Slightly lower: allows strong but not overpowering stylization
    "tv_weight": 1e2,         # Keeps pixel-level smoothness (too high = overly blurry)

    # Choose optimizer:
    "optimizer": "adam",   # More stable convergence and better final output (Adam also supported)

    # Pretrained model used to extract features
    "model": "vgg16",       # Deeper model than vgg16 — captures more detailed features

    # Initialization method for the optimizing image
    "init_method": "random",  # Can be "content", "style", or "random"
                               # "content": more stable, faster convergence
                               # "random": more creativity, unstable
                               # "style": can overly distort content

    # Frequency at which intermediate images are saved
    "saving_freq": 1,       # Every 5 iterations → useful for making progress videos

    # Paths to required directories — must be correctly set to avoid file errors
    "content_images_dir": content_images_dir,
    "style_images_dir": style_images_dir,
    "output_img_dir": output_img_dir,

    # Image saving format (see above)
    "img_format": img_format,
}

# %% [markdown]
# # **`7.`** Run the Style Transfer Process

# %%
# Call the main function to perform neural style transfer
# All outputs will be saved in the directory returned by this function
results_path = neural_style_transfer(optimization_config)
# Out:
# C:\Users\saomy\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\saomy\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Using vgg16 in the optimization procedure.
# Adam | iteration: 000, total loss=27948097536.0000, content_loss=12610676562.5000, style loss=147080089.6000, tv loss=15190339200.0000
# Adam | iteration: 001, total loss=23144196096.0000, content_loss=8701750000.0000, style loss=74992460.8000, tv loss=14367452800.0000
# Adam | iteration: 002, total loss=19813142528.0000, content_loss=6249530078.1250, style loss=41806624.0000, tv loss=13521804800.0000
# Adam | iteration: 003, total loss=17455468544.0000, content_loss=4767692968.7500, style loss=26336208.0000, tv loss=12661440000.0000
# Adam | iteration: 004, total loss=15668339712.0000, content_loss=3848325390.6250, style loss=18653096.0000, tv loss=11801361600.0000
# Adam | iteration: 005, total loss=14204331008.0000, content_loss=3232678320.3125, style loss=14592750.4000, tv loss=10957060000.0000
# Adam | iteration: 006, total loss=12936210432.0000, content_loss=2783733593.7500, style loss=12376666.4000, tv loss=10140100800.0000
# Adam | iteration: 007, total loss=11809922048.0000, content_loss=2438859179.6875, style loss=11199663.2000, tv loss=9359863200.0000
# Adam | iteration: 008, total loss=10800388096.0000, content_loss=2167560546.8750, style loss=10634160.0000, tv loss=8622193600.0000
# Adam | iteration: 009, total loss=9893202944.0000, content_loss=1953070117.1875, style loss=10432016.8000, tv loss=7929700800.0000
# Adam | iteration: 010, total loss=9077810176.0000, content_loss=1782418750.0000, style loss=10435412.8000, tv loss=7284956000.0000
# Adam | iteration: 011, total loss=8344378368.0000, content_loss=1645161523.4375, style loss=10543896.0000, tv loss=6688672800.0000
# Adam | iteration: 012, total loss=7683762688.0000, content_loss=1533055664.0625, style loss=10699519.2000, tv loss=6140007200.0000
# Adam | iteration: 013, total loss=7089665024.0000, content_loss=1440574121.0938, style loss=10870031.2000, tv loss=5638220800.0000
# Adam | iteration: 014, total loss=6556019712.0000, content_loss=1363036132.8125, style loss=11035792.8000, tv loss=5181948000.0000
# Adam | iteration: 015, total loss=6076649984.0000, content_loss=1297116894.5312, style loss=11187507.2000, tv loss=4768345600.0000
# Adam | iteration: 016, total loss=5646163456.0000, content_loss=1239693750.0000, style loss=11322496.0000, tv loss=4395147200.0000
# Adam | iteration: 017, total loss=5259189248.0000, content_loss=1188842773.4375, style loss=11439863.2000, tv loss=4058906400.0000
# Adam | iteration: 018, total loss=4912321024.0000, content_loss=1143189746.0938, style loss=11538519.2000, tv loss=3757592800.0000
# Adam | iteration: 019, total loss=4601307136.0000, content_loss=1102054492.1875, style loss=11619048.0000, tv loss=3487633600.0000
# Adam | iteration: 020, total loss=4322945024.0000, content_loss=1064789355.4688, style loss=11683088.0000, tv loss=3246472400.0000
# Adam | iteration: 021, total loss=4073275904.0000, content_loss=1030792675.7812, style loss=11732583.2000, tv loss=3030750800.0000
# Adam | iteration: 022, total loss=3848909824.0000, content_loss=999416210.9375, style loss=11769780.8000, tv loss=2837724000.0000
# Adam | iteration: 023, total loss=3646083328.0000, content_loss=970016113.2812, style loss=11797066.4000, tv loss=2664270000.0000
# Adam | iteration: 024, total loss=3461958144.0000, content_loss=942335839.8438, style loss=11814771.2000, tv loss=2507807600.0000
# Adam | iteration: 025, total loss=3293804032.0000, content_loss=916212597.6562, style loss=11823868.8000, tv loss=2365767600.0000
# Adam | iteration: 026, total loss=3139514880.0000, content_loss=891633789.0625, style loss=11824733.6000, tv loss=2236056400.0000
# Adam | iteration: 027, total loss=2997973504.0000, content_loss=868621484.3750, style loss=11818779.2000, tv loss=2117533200.0000
# Adam | iteration: 028, total loss=2867003904.0000, content_loss=846922460.9375, style loss=11807063.2000, tv loss=2008274400.0000
# Adam | iteration: 029, total loss=2745924096.0000, content_loss=826453222.6562, style loss=11790777.6000, tv loss=1907680000.0000
# Adam | iteration: 030, total loss=2633394688.0000, content_loss=806994873.0469, style loss=11771372.8000, tv loss=1814628400.0000
# Adam | iteration: 031, total loss=2527819008.0000, content_loss=788143457.0312, style loss=11748870.4000, tv loss=1727926600.0000
# Adam | iteration: 032, total loss=2428426240.0000, content_loss=770159667.9688, style loss=11722924.8000, tv loss=1646543800.0000
# Adam | iteration: 033, total loss=2335087360.0000, content_loss=753279882.8125, style loss=11694751.2000, tv loss=1570112800.0000
# Adam | iteration: 034, total loss=2247562496.0000, content_loss=737321289.0625, style loss=11664156.0000, tv loss=1498577000.0000
# Adam | iteration: 035, total loss=2165021440.0000, content_loss=722222802.7344, style loss=11632064.8000, tv loss=1431166600.0000
# Adam | iteration: 036, total loss=2087201024.0000, content_loss=707800683.5938, style loss=11596596.0000, tv loss=1367803800.0000
# Adam | iteration: 037, total loss=2014341888.0000, content_loss=694315917.9688, style loss=11559036.8000, tv loss=1308467000.0000
# Adam | iteration: 038, total loss=1945684992.0000, content_loss=681463232.4219, style loss=11518126.4000, tv loss=1252703600.0000
# Adam | iteration: 039, total loss=1880566016.0000, content_loss=668968212.8906, style loss=11473680.0000, tv loss=1200124200.0000
# Adam | iteration: 040, total loss=1818513920.0000, content_loss=657039257.8125, style loss=11427378.4000, tv loss=1150047300.0000
# Adam | iteration: 041, total loss=1760050432.0000, content_loss=645758935.5469, style loss=11376353.6000, tv loss=1102915200.0000
# Adam | iteration: 042, total loss=1705367040.0000, content_loss=635128271.4844, style loss=11321190.4000, tv loss=1058917600.0000
# Adam | iteration: 043, total loss=1654174720.0000, content_loss=625112060.5469, style loss=11266408.0000, tv loss=1017796300.0000
# Adam | iteration: 044, total loss=1605907456.0000, content_loss=615570361.3281, style loss=11212155.2000, tv loss=979124900.0000
# Adam | iteration: 045, total loss=1560763520.0000, content_loss=606566259.7656, style loss=11157794.4000, tv loss=943039400.0000
# Adam | iteration: 046, total loss=1518011136.0000, content_loss=597990576.1719, style loss=11102432.8000, tv loss=908918100.0000
# Adam | iteration: 047, total loss=1477587712.0000, content_loss=589623486.3281, style loss=11042959.2000, tv loss=876921300.0000
# Adam | iteration: 048, total loss=1439335296.0000, content_loss=581460937.5000, style loss=10980568.0000, tv loss=846893800.0000
# Adam | iteration: 049, total loss=1403359104.0000, content_loss=573511376.9531, style loss=10913772.8000, tv loss=818933950.0000
# Adam | iteration: 050, total loss=1369415168.0000, content_loss=565615185.5469, style loss=10846908.0000, tv loss=792953100.0000
# Adam | iteration: 051, total loss=1337585664.0000, content_loss=557890673.8281, style loss=10778820.0000, tv loss=768916200.0000
# Adam | iteration: 052, total loss=1307646208.0000, content_loss=550372558.5938, style loss=10710223.2000, tv loss=746563550.0000
# Adam | iteration: 053, total loss=1279226624.0000, content_loss=543014355.4688, style loss=10641117.6000, tv loss=725571200.0000
# Adam | iteration: 054, total loss=1252237312.0000, content_loss=535900781.2500, style loss=10569112.8000, tv loss=705767400.0000
# Adam | iteration: 055, total loss=1226610816.0000, content_loss=528975830.0781, style loss=10493961.6000, tv loss=687141000.0000
# Adam | iteration: 056, total loss=1202474240.0000, content_loss=522168847.6562, style loss=10419560.0000, tv loss=669885900.0000
# Adam | iteration: 057, total loss=1179769600.0000, content_loss=515376464.8438, style loss=10346588.8000, tv loss=654046600.0000
# Adam | iteration: 058, total loss=1158226816.0000, content_loss=508786425.7812, style loss=10276331.2000, tv loss=639164000.0000
# Adam | iteration: 059, total loss=1138169088.0000, content_loss=502517285.1562, style loss=10206250.4000, tv loss=625445550.0000
# Adam | iteration: 060, total loss=1118930432.0000, content_loss=496327539.0625, style loss=10137524.8000, tv loss=612465400.0000
# Adam | iteration: 061, total loss=1100680576.0000, content_loss=490315722.6562, style loss=10068440.0000, tv loss=600296400.0000
# Adam | iteration: 062, total loss=1083656448.0000, content_loss=484505273.4375, style loss=9998072.8000, tv loss=589153050.0000
# Adam | iteration: 063, total loss=1067515008.0000, content_loss=478867236.3281, style loss=9929840.8000, tv loss=578717900.0000
# Adam | iteration: 064, total loss=1052157056.0000, content_loss=473453125.0000, style loss=9865066.4000, tv loss=568838900.0000
# Adam | iteration: 065, total loss=1037516800.0000, content_loss=468162548.8281, style loss=9801615.2000, tv loss=559552650.0000
# Adam | iteration: 066, total loss=1023725952.0000, content_loss=462980468.7500, style loss=9737200.0000, tv loss=551008250.0000
# Adam | iteration: 067, total loss=1011115136.0000, content_loss=458117138.6719, style loss=9671940.0000, tv loss=543326000.0000
# Adam | iteration: 068, total loss=998804096.0000, content_loss=453287158.2031, style loss=9609850.4000, tv loss=535907100.0000
# Adam | iteration: 069, total loss=986962880.0000, content_loss=448528710.9375, style loss=9551510.4000, tv loss=528882650.0000
# Adam | iteration: 070, total loss=975798784.0000, content_loss=443852246.0938, style loss=9492902.4000, tv loss=522453650.0000
# Adam | iteration: 071, total loss=965451456.0000, content_loss=439342773.4375, style loss=9435509.6000, tv loss=516673150.0000
# Adam | iteration: 072, total loss=955764480.0000, content_loss=434990869.1406, style loss=9378368.0000, tv loss=511395200.0000
# Adam | iteration: 073, total loss=946135936.0000, content_loss=430622070.3125, style loss=9325400.8000, tv loss=506188400.0000
# Adam | iteration: 074, total loss=937411968.0000, content_loss=426550488.2812, style loss=9276947.2000, tv loss=501584550.0000
# Adam | iteration: 075, total loss=928834560.0000, content_loss=422395312.5000, style loss=9225948.8000, tv loss=497213300.0000
# Adam | iteration: 076, total loss=920445056.0000, content_loss=418400341.7969, style loss=9179434.4000, tv loss=492865300.0000
# Adam | iteration: 077, total loss=912769664.0000, content_loss=414395507.8125, style loss=9136373.6000, tv loss=489237800.0000
# Adam | iteration: 078, total loss=905363840.0000, content_loss=410506738.2812, style loss=9091515.2000, tv loss=485765600.0000
# Adam | iteration: 079, total loss=898049664.0000, content_loss=406677856.4453, style loss=9049175.2000, tv loss=482322650.0000
# Adam | iteration: 080, total loss=891267392.0000, content_loss=403036962.8906, style loss=9009116.0000, tv loss=479221300.0000
# Adam | iteration: 081, total loss=884565056.0000, content_loss=399238500.9766, style loss=8971112.8000, tv loss=476355450.0000
# Adam | iteration: 082, total loss=878127616.0000, content_loss=395595556.6406, style loss=8934233.6000, tv loss=473597800.0000
# Adam | iteration: 083, total loss=871878848.0000, content_loss=391827416.9922, style loss=8897832.0000, tv loss=471153600.0000
# Adam | iteration: 084, total loss=865839104.0000, content_loss=388157446.2891, style loss=8864694.4000, tv loss=468816950.0000
# Adam | iteration: 085, total loss=860209408.0000, content_loss=384775341.7969, style loss=8834696.0000, tv loss=466599400.0000
# Adam | iteration: 086, total loss=854495936.0000, content_loss=381436743.1641, style loss=8806406.4000, tv loss=464252800.0000
# Adam | iteration: 087, total loss=849046016.0000, content_loss=377936865.2344, style loss=8777336.8000, tv loss=462331850.0000
# Adam | iteration: 088, total loss=843803776.0000, content_loss=374349511.7188, style loss=8749767.2000, tv loss=460704500.0000
# Adam | iteration: 089, total loss=838928768.0000, content_loss=370932055.6641, style loss=8723420.0000, tv loss=459273250.0000
# Adam | iteration: 090, total loss=834097024.0000, content_loss=367574682.6172, style loss=8697218.4000, tv loss=457825150.0000
# Adam | iteration: 091, total loss=828985472.0000, content_loss=364231958.0078, style loss=8674511.2000, tv loss=456079000.0000
# Adam | iteration: 092, total loss=824398912.0000, content_loss=361083251.9531, style loss=8652655.2000, tv loss=454663000.0000
# Adam | iteration: 093, total loss=820229760.0000, content_loss=357930590.8203, style loss=8630986.4000, tv loss=453668200.0000
# Adam | iteration: 094, total loss=815768192.0000, content_loss=354714501.9531, style loss=8609940.8000, tv loss=452443700.0000
# Adam | iteration: 095, total loss=811608448.0000, content_loss=351679956.0547, style loss=8589950.4000, tv loss=451338500.0000
# Adam | iteration: 096, total loss=807356160.0000, content_loss=348523437.5000, style loss=8570532.0000, tv loss=450262200.0000
# Adam | iteration: 097, total loss=803412480.0000, content_loss=345546777.3438, style loss=8556097.6000, tv loss=449309600.0000
# Adam | iteration: 098, total loss=799479296.0000, content_loss=342594702.1484, style loss=8540360.0000, tv loss=448344250.0000
# Adam | iteration: 099, total loss=795797120.0000, content_loss=339610888.6719, style loss=8522083.2000, tv loss=447664200.0000
# Adam | iteration: 100, total loss=792292672.0000, content_loss=336673291.0156, style loss=8503643.2000, tv loss=447115750.0000
# Adam | iteration: 101, total loss=788866560.0000, content_loss=333776586.9141, style loss=8489357.6000, tv loss=446600650.0000
# Adam | iteration: 102, total loss=785302400.0000, content_loss=330919458.0078, style loss=8478190.4000, tv loss=445904800.0000
# Adam | iteration: 103, total loss=781950848.0000, content_loss=328185205.0781, style loss=8465541.6000, tv loss=445300050.0000
# Adam | iteration: 104, total loss=778870720.0000, content_loss=325617089.8438, style loss=8451758.4000, tv loss=444801900.0000
# Adam | iteration: 105, total loss=775650432.0000, content_loss=323035791.0156, style loss=8439219.2000, tv loss=444175400.0000
# Adam | iteration: 106, total loss=772519104.0000, content_loss=320602563.4766, style loss=8427545.6000, tv loss=443489000.0000
# Adam | iteration: 107, total loss=769387968.0000, content_loss=318124707.0312, style loss=8415652.0000, tv loss=442847600.0000
# Adam | iteration: 108, total loss=766611584.0000, content_loss=315667041.0156, style loss=8405449.6000, tv loss=442539150.0000
# Adam | iteration: 109, total loss=763955840.0000, content_loss=313348486.3281, style loss=8394761.6000, tv loss=442212600.0000
# Adam | iteration: 110, total loss=760930560.0000, content_loss=311014135.7422, style loss=8384163.2000, tv loss=441532300.0000
# Adam | iteration: 111, total loss=758151936.0000, content_loss=308823706.0547, style loss=8374671.2000, tv loss=440953600.0000
# Adam | iteration: 112, total loss=755523968.0000, content_loss=306724584.9609, style loss=8365598.4000, tv loss=440433750.0000
# Adam | iteration: 113, total loss=752967872.0000, content_loss=304434326.1719, style loss=8358232.0000, tv loss=440175300.0000
# Adam | iteration: 114, total loss=750866048.0000, content_loss=302528564.4531, style loss=8345212.0000, tv loss=439992300.0000
# Adam | iteration: 115, total loss=748261760.0000, content_loss=300340600.5859, style loss=8335688.0000, tv loss=439585500.0000
# Adam | iteration: 116, total loss=746099328.0000, content_loss=298414331.0547, style loss=8328609.6000, tv loss=439356400.0000
# Adam | iteration: 117, total loss=743814400.0000, content_loss=296445507.8125, style loss=8320047.2000, tv loss=439048900.0000
# Adam | iteration: 118, total loss=741670144.0000, content_loss=294501025.3906, style loss=8309344.0000, tv loss=438859800.0000
# Adam | iteration: 119, total loss=739557632.0000, content_loss=292606250.0000, style loss=8298752.0000, tv loss=438652600.0000
# Adam | iteration: 120, total loss=737198080.0000, content_loss=290648608.3984, style loss=8289879.2000, tv loss=438259600.0000
# Adam | iteration: 121, total loss=735294848.0000, content_loss=289044775.3906, style loss=8281735.2000, tv loss=437968400.0000
# Adam | iteration: 122, total loss=733108096.0000, content_loss=287114624.0234, style loss=8274348.8000, tv loss=437719100.0000
# Adam | iteration: 123, total loss=731525376.0000, content_loss=285485424.8047, style loss=8263678.4000, tv loss=437776300.0000
# Adam | iteration: 124, total loss=729251136.0000, content_loss=283554492.1875, style loss=8255932.8000, tv loss=437440700.0000
# Adam | iteration: 125, total loss=727508544.0000, content_loss=282074877.9297, style loss=8248359.2000, tv loss=437185300.0000
# Adam | iteration: 126, total loss=725631872.0000, content_loss=280352978.5156, style loss=8238583.2000, tv loss=437040300.0000
# Adam | iteration: 127, total loss=723945472.0000, content_loss=278879760.7422, style loss=8232051.2000, tv loss=436833650.0000
# Adam | iteration: 128, total loss=722138240.0000, content_loss=277550488.2812, style loss=8223197.6000, tv loss=436364500.0000
# Adam | iteration: 129, total loss=720503424.0000, content_loss=275968066.4062, style loss=8214184.8000, tv loss=436321200.0000
# Adam | iteration: 130, total loss=718816768.0000, content_loss=274705175.7812, style loss=8204181.6000, tv loss=435907400.0000
# Adam | iteration: 131, total loss=716965952.0000, content_loss=273094140.6250, style loss=8199096.0000, tv loss=435672700.0000
# Adam | iteration: 132, total loss=715614080.0000, content_loss=271859155.2734, style loss=8190804.0000, tv loss=435564100.0000
# Adam | iteration: 133, total loss=714404352.0000, content_loss=270583544.9219, style loss=8182600.0000, tv loss=435638200.0000
# Adam | iteration: 134, total loss=712786688.0000, content_loss=269361694.3359, style loss=8173374.4000, tv loss=435251600.0000
# Adam | iteration: 135, total loss=711188736.0000, content_loss=268003588.8672, style loss=8167691.2000, tv loss=435017500.0000
# Adam | iteration: 136, total loss=709916544.0000, content_loss=266763208.0078, style loss=8159119.2000, tv loss=434994200.0000
# Adam | iteration: 137, total loss=708066432.0000, content_loss=265277758.7891, style loss=8151829.6000, tv loss=434636800.0000
# Adam | iteration: 138, total loss=707101824.0000, content_loss=264193920.8984, style loss=8142964.8000, tv loss=434764900.0000
# Adam | iteration: 139, total loss=705795456.0000, content_loss=262896801.7578, style loss=8133048.8000, tv loss=434765600.0000
# Adam | iteration: 140, total loss=704308480.0000, content_loss=261909692.3828, style loss=8127903.2000, tv loss=434270900.0000
# Adam | iteration: 141, total loss=703120768.0000, content_loss=260768774.4141, style loss=8121622.4000, tv loss=434230400.0000
# Adam | iteration: 142, total loss=701645248.0000, content_loss=259483544.9219, style loss=8115456.8000, tv loss=434046250.0000
# Adam | iteration: 143, total loss=700546432.0000, content_loss=258348999.0234, style loss=8106904.8000, tv loss=434090500.0000
# Adam | iteration: 144, total loss=699211904.0000, content_loss=257159814.4531, style loss=8100180.0000, tv loss=433951900.0000
# Adam | iteration: 145, total loss=698048512.0000, content_loss=255945434.5703, style loss=8093458.4000, tv loss=434009600.0000
# Adam | iteration: 146, total loss=696977216.0000, content_loss=254956982.4219, style loss=8088069.6000, tv loss=433932150.0000
# Adam | iteration: 147, total loss=695892160.0000, content_loss=254014965.8203, style loss=8083042.4000, tv loss=433794150.0000
# Adam | iteration: 148, total loss=694834880.0000, content_loss=253135156.2500, style loss=8077216.0000, tv loss=433622500.0000
# Adam | iteration: 149, total loss=693566144.0000, content_loss=252126098.6328, style loss=8071056.8000, tv loss=433369000.0000
# Adam | iteration: 150, total loss=692467328.0000, content_loss=251204956.0547, style loss=8064068.8000, tv loss=433198300.0000
# Adam | iteration: 151, total loss=691424832.0000, content_loss=250287792.9688, style loss=8058819.2000, tv loss=433078250.0000
# Adam | iteration: 152, total loss=690357440.0000, content_loss=249562500.0000, style loss=8051661.6000, tv loss=432743300.0000
# Adam | iteration: 153, total loss=689223040.0000, content_loss=248557861.3281, style loss=8046151.2000, tv loss=432619000.0000
# Adam | iteration: 154, total loss=688504512.0000, content_loss=247840942.3828, style loss=8041352.8000, tv loss=432622200.0000
# Adam | iteration: 155, total loss=686901504.0000, content_loss=246662695.3125, style loss=8039346.4000, tv loss=432199500.0000
# Adam | iteration: 156, total loss=686046080.0000, content_loss=246023901.3672, style loss=8032048.8000, tv loss=431990100.0000
# Adam | iteration: 157, total loss=685220224.0000, content_loss=245083593.7500, style loss=8024947.2000, tv loss=432111700.0000
# Adam | iteration: 158, total loss=684285184.0000, content_loss=244205371.0938, style loss=8020060.8000, tv loss=432059700.0000
# Adam | iteration: 159, total loss=683467264.0000, content_loss=243449584.9609, style loss=8016014.4000, tv loss=432001650.0000
# Adam | iteration: 160, total loss=682616064.0000, content_loss=242658789.0625, style loss=8013364.0000, tv loss=431943950.0000
# Adam | iteration: 161, total loss=681583104.0000, content_loss=241898339.8438, style loss=8006424.8000, tv loss=431678300.0000
# Adam | iteration: 162, total loss=680912128.0000, content_loss=241125390.6250, style loss=7999941.6000, tv loss=431786800.0000
# Adam | iteration: 163, total loss=679889152.0000, content_loss=240306738.2812, style loss=7995405.6000, tv loss=431587050.0000
# Adam | iteration: 164, total loss=679145024.0000, content_loss=239589233.3984, style loss=7988153.6000, tv loss=431567650.0000
# Adam | iteration: 165, total loss=678311680.0000, content_loss=238679516.6016, style loss=7988998.4000, tv loss=431643200.0000
# Adam | iteration: 166, total loss=677642368.0000, content_loss=238126391.6016, style loss=7983691.2000, tv loss=431532300.0000
# Adam | iteration: 167, total loss=676688896.0000, content_loss=237272412.1094, style loss=7980055.2000, tv loss=431436400.0000
# Adam | iteration: 168, total loss=676211520.0000, content_loss=236688085.9375, style loss=7973942.4000, tv loss=431549500.0000
# Adam | iteration: 169, total loss=675382144.0000, content_loss=236057690.4297, style loss=7972261.6000, tv loss=431352200.0000
# Adam | iteration: 170, total loss=674526592.0000, content_loss=235353881.8359, style loss=7968320.8000, tv loss=431204400.0000
# Adam | iteration: 171, total loss=673759488.0000, content_loss=234805932.6172, style loss=7966644.0000, tv loss=430986900.0000
# Adam | iteration: 172, total loss=673052416.0000, content_loss=234044238.2812, style loss=7960614.4000, tv loss=431047550.0000
# Adam | iteration: 173, total loss=672375232.0000, content_loss=233362646.4844, style loss=7954876.8000, tv loss=431057700.0000
# Adam | iteration: 174, total loss=671593152.0000, content_loss=232613989.2578, style loss=7950969.6000, tv loss=431028200.0000
# Adam | iteration: 175, total loss=671252480.0000, content_loss=232092309.5703, style loss=7948304.0000, tv loss=431211850.0000
# Adam | iteration: 176, total loss=670521408.0000, content_loss=231527563.4766, style loss=7941767.2000, tv loss=431052050.0000
# Adam | iteration: 177, total loss=670041024.0000, content_loss=230954711.9141, style loss=7940184.8000, tv loss=431146150.0000
# Adam | iteration: 178, total loss=669475072.0000, content_loss=230390942.3828, style loss=7937368.0000, tv loss=431146750.0000
# Adam | iteration: 179, total loss=668745600.0000, content_loss=229700537.1094, style loss=7931607.2000, tv loss=431113450.0000
# Adam | iteration: 180, total loss=668088448.0000, content_loss=229098144.5312, style loss=7927641.6000, tv loss=431062700.0000
# Adam | iteration: 181, total loss=667530240.0000, content_loss=228479858.3984, style loss=7924321.6000, tv loss=431126050.0000
# Adam | iteration: 182, total loss=667000064.0000, content_loss=228108886.7188, style loss=7922580.8000, tv loss=430968600.0000
# Adam | iteration: 183, total loss=666081280.0000, content_loss=227366088.8672, style loss=7919280.8000, tv loss=430795900.0000
# Adam | iteration: 184, total loss=665824192.0000, content_loss=227042211.9141, style loss=7914664.8000, tv loss=430867300.0000
# Adam | iteration: 185, total loss=664890944.0000, content_loss=226464526.3672, style loss=7914692.0000, tv loss=430511700.0000
# Adam | iteration: 186, total loss=664275968.0000, content_loss=226009985.3516, style loss=7911606.4000, tv loss=430354400.0000
# Adam | iteration: 187, total loss=663589760.0000, content_loss=225382421.8750, style loss=7908505.6000, tv loss=430298850.0000
# Adam | iteration: 188, total loss=662877440.0000, content_loss=224772534.1797, style loss=7906900.8000, tv loss=430198000.0000
# Adam | iteration: 189, total loss=662440832.0000, content_loss=224298413.0859, style loss=7904647.2000, tv loss=430237750.0000
# Adam | iteration: 190, total loss=661579008.0000, content_loss=223738281.2500, style loss=7903839.2000, tv loss=429936900.0000
# Adam | iteration: 191, total loss=661008320.0000, content_loss=223323071.2891, style loss=7901048.8000, tv loss=429784200.0000
# Adam | iteration: 192, total loss=660441472.0000, content_loss=222582275.3906, style loss=7897738.4000, tv loss=429961450.0000
# Adam | iteration: 193, total loss=659982336.0000, content_loss=222049951.1719, style loss=7896307.2000, tv loss=430036050.0000
# Adam | iteration: 194, total loss=659529920.0000, content_loss=221569970.7031, style loss=7894208.0000, tv loss=430065750.0000
# Adam | iteration: 195, total loss=658751104.0000, content_loss=221058325.1953, style loss=7891268.8000, tv loss=429801550.0000
# Adam | iteration: 196, total loss=658365376.0000, content_loss=220649145.5078, style loss=7885649.6000, tv loss=429830550.0000
# Adam | iteration: 197, total loss=657801472.0000, content_loss=220236621.0938, style loss=7883776.8000, tv loss=429681050.0000
# Adam | iteration: 198, total loss=657451456.0000, content_loss=219851147.4609, style loss=7880309.6000, tv loss=429720000.0000
# Adam | iteration: 199, total loss=657050496.0000, content_loss=219445019.5312, style loss=7878874.4000, tv loss=429726600.0000
# Adam | iteration: 200, total loss=656289792.0000, content_loss=218975830.0781, style loss=7876619.2000, tv loss=429437350.0000
# Adam | iteration: 201, total loss=655757696.0000, content_loss=218518603.5156, style loss=7872898.4000, tv loss=429366200.0000
# Adam | iteration: 202, total loss=655480448.0000, content_loss=218256127.9297, style loss=7871207.2000, tv loss=429353100.0000
# Adam | iteration: 203, total loss=654924160.0000, content_loss=217828002.9297, style loss=7871396.8000, tv loss=429224800.0000
# Adam | iteration: 204, total loss=654231296.0000, content_loss=217476733.3984, style loss=7868676.8000, tv loss=428885850.0000
# Adam | iteration: 205, total loss=654194816.0000, content_loss=217280688.4766, style loss=7865744.8000, tv loss=429048400.0000
# Adam | iteration: 206, total loss=653935104.0000, content_loss=216893676.7578, style loss=7861598.4000, tv loss=429179850.0000
# Adam | iteration: 207, total loss=653158976.0000, content_loss=216508349.6094, style loss=7860046.4000, tv loss=428790600.0000
# Adam | iteration: 208, total loss=652726784.0000, content_loss=216099072.2656, style loss=7859774.4000, tv loss=428767950.0000
# Adam | iteration: 209, total loss=652215296.0000, content_loss=215564941.4062, style loss=7857771.2000, tv loss=428792600.0000
# Adam | iteration: 210, total loss=652227072.0000, content_loss=215206274.4141, style loss=7852708.0000, tv loss=429168100.0000
# Adam | iteration: 211, total loss=651625216.0000, content_loss=214757324.2188, style loss=7854447.2000, tv loss=429013400.0000
# Adam | iteration: 212, total loss=651227648.0000, content_loss=214479931.6406, style loss=7853671.2000, tv loss=428894000.0000
# Adam | iteration: 213, total loss=650614528.0000, content_loss=214110302.7344, style loss=7853166.4000, tv loss=428651050.0000
# Adam | iteration: 214, total loss=650460992.0000, content_loss=213987304.6875, style loss=7849752.8000, tv loss=428623950.0000
# Adam | iteration: 215, total loss=650071744.0000, content_loss=213586035.1562, style loss=7845420.8000, tv loss=428640300.0000
# Adam | iteration: 216, total loss=649743296.0000, content_loss=213238134.7656, style loss=7842648.8000, tv loss=428662500.0000
# Adam | iteration: 217, total loss=649555328.0000, content_loss=212939331.0547, style loss=7841056.8000, tv loss=428774900.0000
# Adam | iteration: 218, total loss=649049728.0000, content_loss=212580517.5781, style loss=7843100.8000, tv loss=428626150.0000
# Adam | iteration: 219, total loss=648825984.0000, content_loss=212289038.0859, style loss=7842422.4000, tv loss=428694550.0000
# Adam | iteration: 220, total loss=648713728.0000, content_loss=212006591.7969, style loss=7838621.6000, tv loss=428868500.0000
# Adam | iteration: 221, total loss=648055232.0000, content_loss=211522705.0781, style loss=7837152.0000, tv loss=428695350.0000
# Adam | iteration: 222, total loss=647969920.0000, content_loss=211464843.7500, style loss=7835110.4000, tv loss=428669950.0000
# Adam | iteration: 223, total loss=647352576.0000, content_loss=211073999.0234, style loss=7833323.2000, tv loss=428445250.0000
# Adam | iteration: 224, total loss=647107136.0000, content_loss=210830249.0234, style loss=7832792.0000, tv loss=428444100.0000
# Adam | iteration: 225, total loss=646696000.0000, content_loss=210499023.4375, style loss=7831872.0000, tv loss=428365100.0000
# Adam | iteration: 226, total loss=646505664.0000, content_loss=210084521.4844, style loss=7828708.0000, tv loss=428592450.0000
# Adam | iteration: 227, total loss=646278912.0000, content_loss=209700048.8281, style loss=7827470.4000, tv loss=428751400.0000
# Adam | iteration: 228, total loss=645590144.0000, content_loss=209306030.2734, style loss=7828136.0000, tv loss=428455950.0000
# Adam | iteration: 229, total loss=645428672.0000, content_loss=209071752.9297, style loss=7827136.0000, tv loss=428529800.0000
# Adam | iteration: 230, total loss=645167872.0000, content_loss=208967822.2656, style loss=7825045.6000, tv loss=428375050.0000
# Adam | iteration: 231, total loss=644687616.0000, content_loss=208644140.6250, style loss=7826228.0000, tv loss=428217200.0000
# Adam | iteration: 232, total loss=644660928.0000, content_loss=208639599.6094, style loss=7822744.8000, tv loss=428198600.0000
# Adam | iteration: 233, total loss=644140096.0000, content_loss=208300366.2109, style loss=7823586.4000, tv loss=428016150.0000
# Adam | iteration: 234, total loss=643768192.0000, content_loss=208103906.2500, style loss=7823871.2000, tv loss=427840450.0000
# Adam | iteration: 235, total loss=643620672.0000, content_loss=207881225.5859, style loss=7823258.4000, tv loss=427916150.0000
# Adam | iteration: 236, total loss=643381760.0000, content_loss=207581030.2734, style loss=7822456.8000, tv loss=427978250.0000
# Adam | iteration: 237, total loss=642661632.0000, content_loss=207275463.8672, style loss=7819543.2000, tv loss=427566650.0000
# Adam | iteration: 238, total loss=642515904.0000, content_loss=206958984.3750, style loss=7820621.6000, tv loss=427736300.0000
# Adam | iteration: 239, total loss=642164864.0000, content_loss=206749389.6484, style loss=7820883.2000, tv loss=427594550.0000
# Adam | iteration: 240, total loss=641584640.0000, content_loss=206504492.1875, style loss=7820036.8000, tv loss=427260100.0000
# Adam | iteration: 241, total loss=641325184.0000, content_loss=206234741.2109, style loss=7819221.6000, tv loss=427271200.0000
# Adam | iteration: 242, total loss=641052992.0000, content_loss=206030029.2969, style loss=7817184.0000, tv loss=427205800.0000
# Adam | iteration: 243, total loss=640605184.0000, content_loss=205787500.0000, style loss=7816400.8000, tv loss=427001300.0000
# Adam | iteration: 244, total loss=640536064.0000, content_loss=205631591.7969, style loss=7815380.8000, tv loss=427089100.0000
# Adam | iteration: 245, total loss=640356608.0000, content_loss=205386376.9531, style loss=7816087.2000, tv loss=427154150.0000
# Adam | iteration: 246, total loss=640160384.0000, content_loss=205284277.3438, style loss=7814598.4000, tv loss=427061550.0000
# Adam | iteration: 247, total loss=639935488.0000, content_loss=205009008.7891, style loss=7814570.4000, tv loss=427111900.0000
# Adam | iteration: 248, total loss=640071232.0000, content_loss=204983374.0234, style loss=7810401.6000, tv loss=427277450.0000
# Adam | iteration: 249, total loss=639677696.0000, content_loss=204642333.9844, style loss=7809690.4000, tv loss=427225700.0000
# Adam | iteration: 250, total loss=639508864.0000, content_loss=204513012.6953, style loss=7809916.0000, tv loss=427185950.0000
# Adam | iteration: 251, total loss=639265280.0000, content_loss=204254382.3242, style loss=7810638.4000, tv loss=427200300.0000
# Adam | iteration: 252, total loss=639260544.0000, content_loss=204175964.3555, style loss=7807201.6000, tv loss=427277400.0000
# Adam | iteration: 253, total loss=638680896.0000, content_loss=203834997.5586, style loss=7809882.4000, tv loss=427036000.0000
# Adam | iteration: 254, total loss=638843904.0000, content_loss=203748156.7383, style loss=7803972.0000, tv loss=427291750.0000
# Adam | iteration: 255, total loss=638399936.0000, content_loss=203463366.6992, style loss=7804869.6000, tv loss=427131700.0000
# Adam | iteration: 256, total loss=638125760.0000, content_loss=203363659.6680, style loss=7804476.0000, tv loss=426957600.0000
# Adam | iteration: 257, total loss=638052864.0000, content_loss=203200000.0000, style loss=7805884.0000, tv loss=427046950.0000
# Adam | iteration: 258, total loss=637823104.0000, content_loss=203132470.7031, style loss=7803963.2000, tv loss=426886700.0000
# Adam | iteration: 259, total loss=637676224.0000, content_loss=202980151.3672, style loss=7803002.4000, tv loss=426893050.0000
# Adam | iteration: 260, total loss=637537536.0000, content_loss=202717846.6797, style loss=7799415.2000, tv loss=427020250.0000
# Adam | iteration: 261, total loss=637376000.0000, content_loss=202497839.3555, style loss=7799864.0000, tv loss=427078300.0000
# Adam | iteration: 262, total loss=637202176.0000, content_loss=202441723.6328, style loss=7798488.8000, tv loss=426962000.0000
# Adam | iteration: 263, total loss=637034368.0000, content_loss=202293139.6484, style loss=7800288.0000, tv loss=426940950.0000
# Adam | iteration: 264, total loss=637023616.0000, content_loss=202099414.0625, style loss=7797648.0000, tv loss=427126550.0000
# Adam | iteration: 265, total loss=636584832.0000, content_loss=201807324.2188, style loss=7797984.0000, tv loss=426979500.0000
# Adam | iteration: 266, total loss=636454400.0000, content_loss=201592321.7773, style loss=7797780.8000, tv loss=427064300.0000
# Adam | iteration: 267, total loss=636347264.0000, content_loss=201598010.2539, style loss=7796769.6000, tv loss=426952500.0000
# Adam | iteration: 268, total loss=635856192.0000, content_loss=201468005.3711, style loss=7795394.4000, tv loss=426592800.0000
# Adam | iteration: 269, total loss=635836864.0000, content_loss=201400048.8281, style loss=7793504.0000, tv loss=426643300.0000
# Adam | iteration: 270, total loss=635813632.0000, content_loss=201221142.5781, style loss=7794148.8000, tv loss=426798350.0000
# Adam | iteration: 271, total loss=635423488.0000, content_loss=201047631.8359, style loss=7794192.0000, tv loss=426581700.0000
# Adam | iteration: 272, total loss=635084480.0000, content_loss=200853845.2148, style loss=7797949.6000, tv loss=426432700.0000
# Adam | iteration: 273, total loss=635165696.0000, content_loss=200917260.7422, style loss=7794197.6000, tv loss=426454200.0000
# Adam | iteration: 274, total loss=634528320.0000, content_loss=200634814.4531, style loss=7796348.0000, tv loss=426097150.0000
# Adam | iteration: 275, total loss=634595456.0000, content_loss=200494262.6953, style loss=7795067.2000, tv loss=426306150.0000
# Adam | iteration: 276, total loss=634537088.0000, content_loss=200265832.5195, style loss=7791923.2000, tv loss=426479300.0000
# Adam | iteration: 277, total loss=634336768.0000, content_loss=200126196.2891, style loss=7794500.0000, tv loss=426416100.0000
# Adam | iteration: 278, total loss=633850112.0000, content_loss=200011254.8828, style loss=7794216.8000, tv loss=426044600.0000
# Adam | iteration: 279, total loss=633915200.0000, content_loss=199939074.7070, style loss=7791635.2000, tv loss=426184500.0000
# Adam | iteration: 280, total loss=633809792.0000, content_loss=199851928.7109, style loss=7793221.6000, tv loss=426164600.0000
# Adam | iteration: 281, total loss=633634496.0000, content_loss=199831604.0039, style loss=7791556.0000, tv loss=426011350.0000
# Adam | iteration: 282, total loss=633324992.0000, content_loss=199677709.9609, style loss=7792247.2000, tv loss=425855050.0000
# Adam | iteration: 283, total loss=633120384.0000, content_loss=199393395.9961, style loss=7789876.8000, tv loss=425937100.0000
# Adam | iteration: 284, total loss=632969472.0000, content_loss=199153967.2852, style loss=7791459.2000, tv loss=426024050.0000
# Adam | iteration: 285, total loss=633049216.0000, content_loss=199195666.5039, style loss=7789794.4000, tv loss=426063750.0000
# Adam | iteration: 286, total loss=632759936.0000, content_loss=199115991.2109, style loss=7791376.8000, tv loss=425852550.0000
# Adam | iteration: 287, total loss=632494848.0000, content_loss=198902087.4023, style loss=7791645.6000, tv loss=425801100.0000
# Adam | iteration: 288, total loss=632538240.0000, content_loss=198839501.9531, style loss=7788784.0000, tv loss=425909950.0000
# Adam | iteration: 289, total loss=632478016.0000, content_loss=198707348.6328, style loss=7791389.6000, tv loss=425979300.0000
# Adam | iteration: 290, total loss=632113408.0000, content_loss=198489965.8203, style loss=7793769.6000, tv loss=425829650.0000
# Adam | iteration: 291, total loss=632082048.0000, content_loss=198392687.9883, style loss=7792674.4000, tv loss=425896700.0000
# Adam | iteration: 292, total loss=631931328.0000, content_loss=198074609.3750, style loss=7792039.2000, tv loss=426064700.0000
# Adam | iteration: 293, total loss=631841472.0000, content_loss=198179492.1875, style loss=7791764.0000, tv loss=425870200.0000
# Adam | iteration: 294, total loss=631345792.0000, content_loss=197955322.2656, style loss=7793352.0000, tv loss=425597100.0000
# Adam | iteration: 295, total loss=631528064.0000, content_loss=198086511.2305, style loss=7791178.4000, tv loss=425650400.0000
# Adam | iteration: 296, total loss=631233152.0000, content_loss=197870422.3633, style loss=7792114.4000, tv loss=425570600.0000
# Adam | iteration: 297, total loss=631016256.0000, content_loss=197699914.5508, style loss=7789212.0000, tv loss=425527150.0000
# Adam | iteration: 298, total loss=630917504.0000, content_loss=197609704.5898, style loss=7788885.6000, tv loss=425518900.0000
# Adam | iteration: 299, total loss=630727424.0000, content_loss=197566491.6992, style loss=7788972.8000, tv loss=425371950.0000
# Adam | iteration: 300, total loss=630487936.0000, content_loss=197309924.3164, style loss=7790654.4000, tv loss=425387400.0000
# Adam | iteration: 301, total loss=630844672.0000, content_loss=197384094.2383, style loss=7787294.4000, tv loss=425673250.0000
# Adam | iteration: 302, total loss=630244864.0000, content_loss=197062475.5859, style loss=7789411.2000, tv loss=425393000.0000
# Adam | iteration: 303, total loss=630429184.0000, content_loss=197247009.2773, style loss=7788321.6000, tv loss=425393850.0000
# Adam | iteration: 304, total loss=630506496.0000, content_loss=197229760.7422, style loss=7788659.2000, tv loss=425488100.0000
# Adam | iteration: 305, total loss=630397312.0000, content_loss=197093249.5117, style loss=7787816.0000, tv loss=425516300.0000
# Adam | iteration: 306, total loss=630244352.0000, content_loss=196991308.5938, style loss=7787688.8000, tv loss=425465300.0000
# Adam | iteration: 307, total loss=629945472.0000, content_loss=197043029.7852, style loss=7789167.2000, tv loss=425113250.0000
# Adam | iteration: 308, total loss=629858816.0000, content_loss=196870654.2969, style loss=7789510.4000, tv loss=425198650.0000
# Adam | iteration: 309, total loss=629960576.0000, content_loss=196887292.4805, style loss=7787690.4000, tv loss=425285600.0000
# Adam | iteration: 310, total loss=629775360.0000, content_loss=196734204.1016, style loss=7787724.8000, tv loss=425253400.0000
# Adam | iteration: 311, total loss=629686400.0000, content_loss=196638537.5977, style loss=7785257.6000, tv loss=425262550.0000
# Adam | iteration: 312, total loss=629682496.0000, content_loss=196479699.7070, style loss=7787811.2000, tv loss=425415000.0000
# Adam | iteration: 313, total loss=629354624.0000, content_loss=196481542.9688, style loss=7789254.4000, tv loss=425083850.0000
# Adam | iteration: 314, total loss=629072576.0000, content_loss=196363818.3594, style loss=7787514.4000, tv loss=424921200.0000
# Adam | iteration: 315, total loss=629327488.0000, content_loss=196207995.6055, style loss=7788120.0000, tv loss=425331400.0000
# Adam | iteration: 316, total loss=629068288.0000, content_loss=196156347.6562, style loss=7787783.2000, tv loss=425124200.0000
# Adam | iteration: 317, total loss=628809600.0000, content_loss=195958117.6758, style loss=7791273.6000, tv loss=425060200.0000
# Adam | iteration: 318, total loss=628815744.0000, content_loss=195940527.3438, style loss=7789360.0000, tv loss=425085900.0000
# Adam | iteration: 319, total loss=628673152.0000, content_loss=195814257.8125, style loss=7788843.2000, tv loss=425070000.0000
# Adam | iteration: 320, total loss=628494528.0000, content_loss=195897424.3164, style loss=7787804.8000, tv loss=424809300.0000
# Adam | iteration: 321, total loss=628257344.0000, content_loss=195695434.5703, style loss=7792096.0000, tv loss=424769800.0000
# Adam | iteration: 322, total loss=628402176.0000, content_loss=195628466.7969, style loss=7786860.0000, tv loss=424986800.0000
# Adam | iteration: 323, total loss=627988608.0000, content_loss=195457653.8086, style loss=7788918.4000, tv loss=424742050.0000
# Adam | iteration: 324, total loss=628279424.0000, content_loss=195480859.3750, style loss=7787438.4000, tv loss=425011100.0000
# Adam | iteration: 325, total loss=627719296.0000, content_loss=195338598.6328, style loss=7789575.2000, tv loss=424591100.0000
# Adam | iteration: 326, total loss=627803072.0000, content_loss=195501232.9102, style loss=7787271.2000, tv loss=424514600.0000
# Adam | iteration: 327, total loss=627806016.0000, content_loss=195300390.6250, style loss=7790326.4000, tv loss=424715300.0000
# Adam | iteration: 328, total loss=627703104.0000, content_loss=195479150.3906, style loss=7787547.2000, tv loss=424436400.0000
# Adam | iteration: 329, total loss=627382464.0000, content_loss=195247790.5273, style loss=7792264.0000, tv loss=424342400.0000
# Adam | iteration: 330, total loss=627516160.0000, content_loss=195132983.3984, style loss=7789416.8000, tv loss=424593750.0000
# Adam | iteration: 331, total loss=627460992.0000, content_loss=194963830.5664, style loss=7789010.4000, tv loss=424708200.0000
# Adam | iteration: 332, total loss=627359232.0000, content_loss=194913073.7305, style loss=7787267.2000, tv loss=424658900.0000
# Adam | iteration: 333, total loss=627307968.0000, content_loss=194933361.8164, style loss=7789597.6000, tv loss=424585000.0000
# Adam | iteration: 334, total loss=626979200.0000, content_loss=194799328.6133, style loss=7791191.2000, tv loss=424388700.0000
# Adam | iteration: 335, total loss=626990592.0000, content_loss=194835949.7070, style loss=7788075.2000, tv loss=424366550.0000
# Adam | iteration: 336, total loss=626720576.0000, content_loss=194729211.4258, style loss=7788410.4000, tv loss=424202950.0000
# Adam | iteration: 337, total loss=626905856.0000, content_loss=194674816.8945, style loss=7788804.0000, tv loss=424442200.0000
# Adam | iteration: 338, total loss=627045632.0000, content_loss=194626855.4688, style loss=7787892.8000, tv loss=424630900.0000
# Adam | iteration: 339, total loss=626598656.0000, content_loss=194353308.1055, style loss=7789918.4000, tv loss=424455400.0000
# Adam | iteration: 340, total loss=626709632.0000, content_loss=194471594.2383, style loss=7786371.2000, tv loss=424451650.0000
# Adam | iteration: 341, total loss=626474432.0000, content_loss=194386376.9531, style loss=7788964.0000, tv loss=424299100.0000
# Adam | iteration: 342, total loss=626482432.0000, content_loss=194367578.1250, style loss=7786785.6000, tv loss=424328100.0000
# Adam | iteration: 343, total loss=626602112.0000, content_loss=194361315.9180, style loss=7789936.0000, tv loss=424450850.0000
# Adam | iteration: 344, total loss=626331136.0000, content_loss=194318737.7930, style loss=7785260.8000, tv loss=424227150.0000
# Adam | iteration: 345, total loss=626411904.0000, content_loss=194306750.4883, style loss=7785239.2000, tv loss=424319900.0000
# Adam | iteration: 346, total loss=626302272.0000, content_loss=194250207.5195, style loss=7788926.4000, tv loss=424263150.0000
# Adam | iteration: 347, total loss=626309248.0000, content_loss=194263317.8711, style loss=7789245.6000, tv loss=424256700.0000
# Adam | iteration: 348, total loss=626371072.0000, content_loss=194199121.0938, style loss=7787892.0000, tv loss=424384100.0000
# Adam | iteration: 349, total loss=626301248.0000, content_loss=193999731.4453, style loss=7787261.6000, tv loss=424514250.0000
# Adam | iteration: 350, total loss=626300544.0000, content_loss=194017651.3672, style loss=7787220.8000, tv loss=424495700.0000
# Adam | iteration: 351, total loss=626063424.0000, content_loss=193821105.9570, style loss=7789156.8000, tv loss=424453200.0000
# Adam | iteration: 352, total loss=626262528.0000, content_loss=193835681.1523, style loss=7786618.4000, tv loss=424640200.0000
# Adam | iteration: 353, total loss=626200896.0000, content_loss=193768115.2344, style loss=7787814.4000, tv loss=424644950.0000
# Adam | iteration: 354, total loss=626121216.0000, content_loss=193792797.8516, style loss=7785804.0000, tv loss=424542600.0000
# Adam | iteration: 355, total loss=626027392.0000, content_loss=193685827.6367, style loss=7788163.2000, tv loss=424553400.0000
# Adam | iteration: 356, total loss=626044416.0000, content_loss=193688952.6367, style loss=7788580.0000, tv loss=424566900.0000
# Adam | iteration: 357, total loss=625724288.0000, content_loss=193490185.5469, style loss=7788541.6000, tv loss=424445550.0000
# Adam | iteration: 358, total loss=625747328.0000, content_loss=193468774.4141, style loss=7787743.2000, tv loss=424490800.0000
# Adam | iteration: 359, total loss=625831680.0000, content_loss=193422473.1445, style loss=7788968.0000, tv loss=424620200.0000
# Adam | iteration: 360, total loss=625847104.0000, content_loss=193299768.0664, style loss=7787341.6000, tv loss=424760000.0000
# Adam | iteration: 361, total loss=625920896.0000, content_loss=193298181.1523, style loss=7786441.6000, tv loss=424836300.0000
# Adam | iteration: 362, total loss=625348096.0000, content_loss=193234765.6250, style loss=7787867.2000, tv loss=424325450.0000
# Adam | iteration: 363, total loss=625505984.0000, content_loss=193390673.8281, style loss=7786336.8000, tv loss=424328950.0000
# Adam | iteration: 364, total loss=625286016.0000, content_loss=193324230.9570, style loss=7784563.2000, tv loss=424177200.0000
# Adam | iteration: 365, total loss=625235840.0000, content_loss=193298986.8164, style loss=7785115.2000, tv loss=424151750.0000
# Adam | iteration: 366, total loss=625238400.0000, content_loss=193213366.6992, style loss=7788436.8000, tv loss=424236600.0000
# Adam | iteration: 367, total loss=625050368.0000, content_loss=193033447.2656, style loss=7790692.0000, tv loss=424226200.0000
# Adam | iteration: 368, total loss=624919872.0000, content_loss=193079992.6758, style loss=7787961.6000, tv loss=424051900.0000
# Adam | iteration: 369, total loss=625179264.0000, content_loss=193080371.0938, style loss=7790116.0000, tv loss=424308800.0000
# ...
# Adam | iteration: 875, total loss=622290048.0000, content_loss=187428637.6953, style loss=7734197.6000, tv loss=427127200.0000
# Adam | iteration: 876, total loss=622083008.0000, content_loss=187457202.1484, style loss=7734179.2000, tv loss=426891650.0000
# Adam | iteration: 877, total loss=622433728.0000, content_loss=187533312.9883, style loss=7735636.8000, tv loss=427164800.0000
# Adam | iteration: 878, total loss=621964736.0000, content_loss=187477978.5156, style loss=7734161.6000, tv loss=426752600.0000
# Adam | iteration: 879, total loss=621963072.0000, content_loss=187555981.4453, style loss=7734819.2000, tv loss=426672250.0000
# Adam | iteration: 880, total loss=622486208.0000, content_loss=187676464.8438, style loss=7734688.0000, tv loss=427075050.0000
# Adam | iteration: 881, total loss=622375680.0000, content_loss=187442102.0508, style loss=7733651.2000, tv loss=427199900.0000
# Adam | iteration: 882, total loss=622139136.0000, content_loss=187485253.9062, style loss=7733457.6000, tv loss=426920450.0000
# Adam | iteration: 883, total loss=622308480.0000, content_loss=187457885.7422, style loss=7734508.0000, tv loss=427116050.0000
# Adam | iteration: 884, total loss=622367680.0000, content_loss=187477807.6172, style loss=7733790.4000, tv loss=427156050.0000
# Adam | iteration: 885, total loss=622327296.0000, content_loss=187405578.6133, style loss=7730931.2000, tv loss=427190800.0000
# Adam | iteration: 886, total loss=622155264.0000, content_loss=187301037.5977, style loss=7732051.2000, tv loss=427122150.0000
# Adam | iteration: 887, total loss=622239616.0000, content_loss=187364343.2617, style loss=7733699.2000, tv loss=427141600.0000
# Adam | iteration: 888, total loss=622623488.0000, content_loss=187340148.9258, style loss=7732640.8000, tv loss=427550700.0000
# Adam | iteration: 889, total loss=622289408.0000, content_loss=187364392.0898, style loss=7732887.2000, tv loss=427192150.0000
# Adam | iteration: 890, total loss=622366336.0000, content_loss=187432360.8398, style loss=7731952.8000, tv loss=427202000.0000
# Adam | iteration: 891, total loss=622229120.0000, content_loss=187539404.2969, style loss=7730308.8000, tv loss=426959400.0000
# Adam | iteration: 892, total loss=622396736.0000, content_loss=187533007.8125, style loss=7729936.8000, tv loss=427133800.0000
# Adam | iteration: 893, total loss=622640128.0000, content_loss=187509924.3164, style loss=7731869.6000, tv loss=427398300.0000
# Adam | iteration: 894, total loss=622123520.0000, content_loss=187359082.0312, style loss=7735083.2000, tv loss=427029300.0000
# Adam | iteration: 895, total loss=622388864.0000, content_loss=187516918.9453, style loss=7734080.8000, tv loss=427137900.0000
# Adam | iteration: 896, total loss=622550016.0000, content_loss=187358789.0625, style loss=7733280.8000, tv loss=427458000.0000
# Adam | iteration: 897, total loss=622726528.0000, content_loss=187397290.0391, style loss=7730915.2000, tv loss=427598300.0000
# Adam | iteration: 898, total loss=622648128.0000, content_loss=187482189.9414, style loss=7730731.2000, tv loss=427435200.0000
# Adam | iteration: 899, total loss=622399744.0000, content_loss=187547253.4180, style loss=7734643.2000, tv loss=427117850.0000
# Adam | iteration: 900, total loss=622525504.0000, content_loss=187681677.2461, style loss=7731903.2000, tv loss=427111950.0000
# Adam | iteration: 901, total loss=622248000.0000, content_loss=187577514.6484, style loss=7730524.8000, tv loss=426939950.0000
# Adam | iteration: 902, total loss=622496512.0000, content_loss=187533435.0586, style loss=7728871.2000, tv loss=427234250.0000
# Adam | iteration: 903, total loss=622526464.0000, content_loss=187461401.3672, style loss=7729423.2000, tv loss=427335650.0000
# Adam | iteration: 904, total loss=622540160.0000, content_loss=187388940.4297, style loss=7729306.4000, tv loss=427421900.0000
# Adam | iteration: 905, total loss=622411392.0000, content_loss=187322338.8672, style loss=7730821.6000, tv loss=427358250.0000
# Adam | iteration: 906, total loss=622692288.0000, content_loss=187379394.5312, style loss=7730210.4000, tv loss=427582700.0000
# Adam | iteration: 907, total loss=622453760.0000, content_loss=187439050.2930, style loss=7734316.8000, tv loss=427280400.0000
# Adam | iteration: 908, total loss=622609152.0000, content_loss=187558447.2656, style loss=7728782.4000, tv loss=427321900.0000
# Adam | iteration: 909, total loss=622655744.0000, content_loss=187339428.7109, style loss=7731020.8000, tv loss=427585300.0000
# Adam | iteration: 910, total loss=622414336.0000, content_loss=187404284.6680, style loss=7729416.0000, tv loss=427280650.0000
# Adam | iteration: 911, total loss=622283520.0000, content_loss=187362988.2812, style loss=7731982.4000, tv loss=427188550.0000
# Adam | iteration: 912, total loss=622456960.0000, content_loss=187437670.8984, style loss=7729276.0000, tv loss=427290000.0000
# Adam | iteration: 913, total loss=622347776.0000, content_loss=187464062.5000, style loss=7733148.0000, tv loss=427150550.0000
# Adam | iteration: 914, total loss=622277248.0000, content_loss=187390039.0625, style loss=7730720.8000, tv loss=427156500.0000
# Adam | iteration: 915, total loss=622432768.0000, content_loss=187317370.6055, style loss=7729626.4000, tv loss=427385800.0000
# Adam | iteration: 916, total loss=622508928.0000, content_loss=187298022.4609, style loss=7729800.8000, tv loss=427481100.0000
# Adam | iteration: 917, total loss=622538944.0000, content_loss=187365295.4102, style loss=7729753.6000, tv loss=427443900.0000
# Adam | iteration: 918, total loss=622461248.0000, content_loss=187327380.3711, style loss=7732443.2000, tv loss=427401400.0000
# Adam | iteration: 919, total loss=622484480.0000, content_loss=187327197.2656, style loss=7731776.0000, tv loss=427425500.0000
# Adam | iteration: 920, total loss=622537408.0000, content_loss=187236914.0625, style loss=7729923.2000, tv loss=427570600.0000
# Adam | iteration: 921, total loss=622636544.0000, content_loss=187324462.8906, style loss=7730410.4000, tv loss=427581700.0000
# Adam | iteration: 922, total loss=622612672.0000, content_loss=187406115.7227, style loss=7730547.2000, tv loss=427476000.0000
# Adam | iteration: 923, total loss=622560512.0000, content_loss=187466625.9766, style loss=7730667.2000, tv loss=427363200.0000
# Adam | iteration: 924, total loss=622697216.0000, content_loss=187543408.2031, style loss=7730220.0000, tv loss=427423600.0000
# Adam | iteration: 925, total loss=622555776.0000, content_loss=187485229.4922, style loss=7730978.4000, tv loss=427339600.0000
# Adam | iteration: 926, total loss=622756288.0000, content_loss=187434899.9023, style loss=7729924.8000, tv loss=427591500.0000
# Adam | iteration: 927, total loss=622670400.0000, content_loss=187298828.1250, style loss=7730461.6000, tv loss=427641100.0000
# Adam | iteration: 928, total loss=622785920.0000, content_loss=187372436.5234, style loss=7729080.8000, tv loss=427684400.0000
# Adam | iteration: 929, total loss=622456960.0000, content_loss=187254553.2227, style loss=7732813.6000, tv loss=427469600.0000
# Adam | iteration: 930, total loss=622536960.0000, content_loss=187268457.0312, style loss=7730370.4000, tv loss=427538100.0000
# Adam | iteration: 931, total loss=622573312.0000, content_loss=187317639.1602, style loss=7731993.6000, tv loss=427523700.0000
# Adam | iteration: 932, total loss=622460672.0000, content_loss=187187866.2109, style loss=7730760.0000, tv loss=427542050.0000
# Adam | iteration: 933, total loss=622605696.0000, content_loss=187223535.1562, style loss=7726959.2000, tv loss=427655200.0000
# Adam | iteration: 934, total loss=622702080.0000, content_loss=187275854.4922, style loss=7730085.6000, tv loss=427696150.0000
# Adam | iteration: 935, total loss=622532672.0000, content_loss=187279199.2188, style loss=7728271.2000, tv loss=427525200.0000
# Adam | iteration: 936, total loss=622632960.0000, content_loss=187348840.3320, style loss=7729190.4000, tv loss=427554950.0000
# Adam | iteration: 937, total loss=622338176.0000, content_loss=187242114.2578, style loss=7730332.8000, tv loss=427365750.0000
# Adam | iteration: 938, total loss=622508032.0000, content_loss=187249768.0664, style loss=7729495.2000, tv loss=427528800.0000
# Adam | iteration: 939, total loss=622564864.0000, content_loss=187316430.6641, style loss=7729347.2000, tv loss=427519100.0000
# Adam | iteration: 940, total loss=622667200.0000, content_loss=187285119.6289, style loss=7730349.6000, tv loss=427651750.0000
# Adam | iteration: 941, total loss=622648128.0000, content_loss=187310351.5625, style loss=7728427.2000, tv loss=427609350.0000
# Adam | iteration: 942, total loss=622478976.0000, content_loss=187113781.7383, style loss=7727887.2000, tv loss=427637300.0000
# Adam | iteration: 943, total loss=622755648.0000, content_loss=187204248.0469, style loss=7727294.4000, tv loss=427824100.0000
# Adam | iteration: 944, total loss=622657728.0000, content_loss=187119079.5898, style loss=7726856.0000, tv loss=427811800.0000
# Adam | iteration: 945, total loss=622745472.0000, content_loss=187208020.0195, style loss=7728472.0000, tv loss=427808950.0000
# Adam | iteration: 946, total loss=622869888.0000, content_loss=187148925.7812, style loss=7728085.6000, tv loss=427992900.0000
# Adam | iteration: 947, total loss=622827776.0000, content_loss=187098962.4023, style loss=7727580.0000, tv loss=428001200.0000
# Adam | iteration: 948, total loss=622771712.0000, content_loss=187093652.3438, style loss=7727297.6000, tv loss=427950800.0000
# Adam | iteration: 949, total loss=622550784.0000, content_loss=187117907.7148, style loss=7727849.6000, tv loss=427705000.0000
# Adam | iteration: 950, total loss=622555520.0000, content_loss=187210632.3242, style loss=7728868.0000, tv loss=427616000.0000
# Adam | iteration: 951, total loss=622658176.0000, content_loss=187201135.2539, style loss=7728920.0000, tv loss=427728100.0000
# Adam | iteration: 952, total loss=622543104.0000, content_loss=187048498.5352, style loss=7731098.4000, tv loss=427763500.0000
# Adam | iteration: 953, total loss=622735296.0000, content_loss=187196276.8555, style loss=7728674.4000, tv loss=427810350.0000
# Adam | iteration: 954, total loss=622548416.0000, content_loss=187045227.0508, style loss=7729314.4000, tv loss=427773900.0000
# Adam | iteration: 955, total loss=622844416.0000, content_loss=187252954.1016, style loss=7725241.6000, tv loss=427866200.0000
# Adam | iteration: 956, total loss=622587584.0000, content_loss=187157275.3906, style loss=7727946.4000, tv loss=427702350.0000
# Adam | iteration: 957, total loss=622562624.0000, content_loss=187442150.8789, style loss=7725996.0000, tv loss=427394500.0000
# Adam | iteration: 958, total loss=622374144.0000, content_loss=187454357.9102, style loss=7729656.8000, tv loss=427190100.0000
# Adam | iteration: 959, total loss=622694016.0000, content_loss=187539807.1289, style loss=7726131.2000, tv loss=427428050.0000
# Adam | iteration: 960, total loss=622651968.0000, content_loss=187559240.7227, style loss=7728805.6000, tv loss=427363900.0000
# Adam | iteration: 961, total loss=622658944.0000, content_loss=187504736.3281, style loss=7727066.4000, tv loss=427427150.0000
# Adam | iteration: 962, total loss=622674048.0000, content_loss=187413940.4297, style loss=7726416.0000, tv loss=427533700.0000
# Adam | iteration: 963, total loss=622807872.0000, content_loss=187389794.9219, style loss=7728986.4000, tv loss=427689100.0000
# Adam | iteration: 964, total loss=622652480.0000, content_loss=187293774.4141, style loss=7730098.4000, tv loss=427628600.0000
# Adam | iteration: 965, total loss=623036544.0000, content_loss=187425878.9062, style loss=7725834.4000, tv loss=427884800.0000
# Adam | iteration: 966, total loss=622878976.0000, content_loss=187267614.7461, style loss=7726928.8000, tv loss=427884400.0000
# Adam | iteration: 967, total loss=622871296.0000, content_loss=187245849.6094, style loss=7726572.8000, tv loss=427898850.0000
# Adam | iteration: 968, total loss=622862144.0000, content_loss=187146191.4062, style loss=7728018.4000, tv loss=427987950.0000
# Adam | iteration: 969, total loss=622732416.0000, content_loss=187123889.1602, style loss=7729196.0000, tv loss=427879300.0000
# Adam | iteration: 970, total loss=622724608.0000, content_loss=187145373.5352, style loss=7727295.2000, tv loss=427851950.0000
# Adam | iteration: 971, total loss=623113472.0000, content_loss=187286962.8906, style loss=7726095.2000, tv loss=428100400.0000
# Adam | iteration: 972, total loss=622763904.0000, content_loss=187219274.9023, style loss=7725480.0000, tv loss=427819100.0000
# Adam | iteration: 973, total loss=622681088.0000, content_loss=187204785.1562, style loss=7724104.0000, tv loss=427752200.0000
# Adam | iteration: 974, total loss=622912000.0000, content_loss=187253735.3516, style loss=7725853.6000, tv loss=427932400.0000
# Adam | iteration: 975, total loss=622640768.0000, content_loss=187260058.5938, style loss=7726410.4000, tv loss=427654300.0000
# Adam | iteration: 976, total loss=622784128.0000, content_loss=187298364.2578, style loss=7729868.0000, tv loss=427755900.0000
# Adam | iteration: 977, total loss=622841856.0000, content_loss=187264318.8477, style loss=7725437.6000, tv loss=427852050.0000
# Adam | iteration: 978, total loss=622686592.0000, content_loss=187078881.8359, style loss=7725369.6000, tv loss=427882300.0000
# Adam | iteration: 979, total loss=622828672.0000, content_loss=187106970.2148, style loss=7725196.0000, tv loss=427996500.0000
# Adam | iteration: 980, total loss=622718208.0000, content_loss=187170251.4648, style loss=7724172.8000, tv loss=427823800.0000
# Adam | iteration: 981, total loss=622786688.0000, content_loss=187275134.2773, style loss=7725977.6000, tv loss=427785600.0000
# Adam | iteration: 982, total loss=622904960.0000, content_loss=187239648.4375, style loss=7725850.4000, tv loss=427939500.0000
# Adam | iteration: 983, total loss=622927360.0000, content_loss=187264196.7773, style loss=7727108.8000, tv loss=427936100.0000
# Adam | iteration: 984, total loss=622846528.0000, content_loss=187186242.6758, style loss=7726421.6000, tv loss=427933900.0000
# Adam | iteration: 985, total loss=623027776.0000, content_loss=187230712.8906, style loss=7724687.2000, tv loss=428072400.0000
# Adam | iteration: 986, total loss=622626816.0000, content_loss=187015527.3438, style loss=7726236.0000, tv loss=427885100.0000
# Adam | iteration: 987, total loss=622891520.0000, content_loss=187068261.7188, style loss=7722641.6000, tv loss=428100600.0000
# Adam | iteration: 988, total loss=622793472.0000, content_loss=186979138.1836, style loss=7726818.4000, tv loss=428087500.0000
# Adam | iteration: 989, total loss=622695808.0000, content_loss=187079150.3906, style loss=7726164.8000, tv loss=427890450.0000
# Adam | iteration: 990, total loss=622675968.0000, content_loss=186971887.2070, style loss=7725050.4000, tv loss=427979050.0000
# Adam | iteration: 991, total loss=622705280.0000, content_loss=186926794.4336, style loss=7725462.4000, tv loss=428053000.0000
# Adam | iteration: 992, total loss=622503936.0000, content_loss=186931384.2773, style loss=7724632.0000, tv loss=427847900.0000
# Adam | iteration: 993, total loss=622799616.0000, content_loss=187032812.5000, style loss=7725486.4000, tv loss=428041300.0000
# Adam | iteration: 994, total loss=622701312.0000, content_loss=187038281.2500, style loss=7726985.6000, tv loss=427936000.0000
# Adam | iteration: 995, total loss=622567808.0000, content_loss=187072241.2109, style loss=7724416.8000, tv loss=427771150.0000
# Adam | iteration: 996, total loss=622724864.0000, content_loss=187165979.0039, style loss=7726051.2000, tv loss=427832800.0000
# Adam | iteration: 997, total loss=622534272.0000, content_loss=187262512.2070, style loss=7726101.6000, tv loss=427545650.0000
# Adam | iteration: 998, total loss=622454848.0000, content_loss=187203454.5898, style loss=7727456.8000, tv loss=427523950.0000
# Adam | iteration: 999, total loss=622579776.0000, content_loss=187141027.8320, style loss=7727286.4000, tv loss=427711500.0000

# %%
# Join all the intermediate photos to create the Video
create_video_from_intermediate_results(results_path, img_format)

# %% [markdown]
# | Parameter        | Value       | Why it's used                                   |
# | ---------------- | ----------- | ----------------------------------------------- |
# | `content_weight` | `1e5`       | Prioritizes preserving shapes and layout.       |
# | `style_weight`   | `1e4`       | Stylizes textures without overwhelming content. |
# | `tv_weight`      | `1`         | Adds slight smoothness (regularization).        |
# | `height`         | `500`       | Balances visual quality and GPU memory usage.   |
# | `lr` (Adam)      | `1e1`       | A high learning rate to update pixels quickly.  |
# | `iterations`     | `1000–3000` | Empirically chosen for quality convergence.     |

# %% [markdown]
# # **`A.`** Check pixel intensity before and after morphing

# %%
import cv2
import matplotlib.pyplot as plt

# Load the two images in RGB format
image_path_1 = "D:/NST/data/output-images/combined_birds_Mona_Lisa/0000.jpg"
image_path_2 = "D:/NST/data/output-images/combined_birds_Mona_Lisa/1001.jpg"

image1 = cv2.imread(image_path_1)  # Load first image in color (RGB)
image2 = cv2.imread(image_path_2)  # Load second image in color (RGB)

# Check if the images are loaded
if image1 is None or image2 is None:
    print("Error: One or both images not found.")
    exit()

# Convert the images from BGR to RGB (OpenCV loads images in BGR by default)
image1_rgb = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2_rgb = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# Define colors for plotting
colors = ('r', 'g', 'b')  # Red, Green, Blue

# Create subplots: 2 rows for images, 2 columns for histograms
fig, axs = plt.subplots(2, 2, figsize=(12, 12))

# Plot the first image
axs[0, 0].imshow(image1_rgb)
axs[0, 0].axis('off')  # Turn off axis
axs[0, 0].set_title("Original Bird image")

# Plot histogram for the first image
for i, col in enumerate(colors):
    hist = cv2.calcHist([image1_rgb], [i], None, [256], [0, 256])
    axs[0, 1].plot(hist, color=col, linewidth=2)
axs[0, 1].set_title("Histogram of Original Image")
axs[0, 1].set_xlim([0, 256])
axs[0, 1].set_xlabel("Pixel Intensity")
axs[0, 1].set_ylabel("Frequency")
axs[0, 1].legend(["Red", "Green", "Blue"])

# Plot the second image
axs[1, 0].imshow(image2_rgb)
axs[1, 0].axis('off')  # Turn off axis
axs[1, 0].set_title("Post Mona Lisa Style merging")

# Plot histogram for the second image
for i, col in enumerate(colors):
    hist = cv2.calcHist([image2_rgb], [i], None, [256], [0, 256])
    axs[1, 1].plot(hist, color=col, linewidth=2)
axs[1, 1].set_title("Histogram post NST using VGG-16")
axs[1, 1].set_xlim([0, 256])
axs[1, 1].set_xlabel("Pixel Intensity")
axs[1, 1].set_ylabel("Frequency")
axs[1, 1].legend(["Red", "Green", "Blue"])

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
